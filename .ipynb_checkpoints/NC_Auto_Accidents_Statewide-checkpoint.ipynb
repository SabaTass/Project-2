# %%
# Dependencies
import requests
import json
from pprint import pprint

# %%
# URL for GET requests to retrieve vehicle data
# crash data for 2016-2019 for State # 37 = NC
url1 = "https://crashviewer.nhtsa.dot.gov/CrashAPI/crashes/GetCaseList?states=37&fromYear=2016&toYear=2019&minNumOfVehicles=1&maxNumOfVehicles=6&format=json"

# %%
# Print the response object to the console
print(requests.get(url1))
# Out:
# <Response [200]>

# %%
# Retrieving data and converting it into JSON
pprint(requests.get(url1).json())
# Out:
# {'Count': 3970,
#  'Message': 'Results returned successfully',
#  'Results': [[{'CountyName': 'ASHE (9)',
#                'CrashDate': '/Date(1453317000000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 3,
#                'St_Case': 370001,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'AVERY (11)',
#                'CrashDate': '/Date(1453405320000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 370002,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'AVERY (11)',
#                'CrashDate': '/Date(1453317480000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 3,
#                'St_Case': 370003,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'BEAUFORT (13)',
#                'CrashDate': '/Date(1452857820000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 370004,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'BERTIE (15)',
#                'CrashDate': '/Date(1451951700000-0500)/',
#                'Fatals': 1,
#                'Peds': 1,
#                'Persons': 1,
#                'St_Case': 370005,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'BLADEN (17)',
#                'CrashDate': '/Date(1453757280000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 370006,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'CABARRUS (25)',
#                'CrashDate': '/Date(1451866500000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 3,
#                'St_Case': 370007,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'CABARRUS (25)',
#                'CrashDate': '/Date(1452741240000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370008,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'CABARRUS (25)',
#                'CrashDate': '/Date(1454280480000-0500)/',
#                'Fatals': 2,
#                'Peds': 0,
#                'Persons': 4,
#                'St_Case': 370009,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'CATAWBA (35)',
#                'CrashDate': '/Date(1453421760000-0500)/',
#                'Fatals': 1,
#                'Peds': 1,
#                'Persons': 2,
#                'St_Case': 370010,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'CATAWBA (35)',
#                'CrashDate': '/Date(1453446000000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370011,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'CHATHAM (37)',
#                'CrashDate': '/Date(1452579060000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370012,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'CHATHAM (37)',
#                'CrashDate': '/Date(1453009500000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370013,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'CHEROKEE (39)',
#                'CrashDate': '/Date(1451922900000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 370014,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'COLUMBUS (47)',
#                'CrashDate': '/Date(1454099580000-0500)/',
#                'Fatals': 2,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 370015,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'CRAVEN (49)',
#                'CrashDate': '/Date(1452091980000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 8,
#                'St_Case': 370016,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 5},
#               {'CountyName': 'CRAVEN (49)',
#                'CrashDate': '/Date(1453863960000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370017,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'CUMBERLAND (51)',
#                'CrashDate': '/Date(1452920100000-0500)/',
#                'Fatals': 2,
#                'Peds': 0,
#                'Persons': 3,
#                'St_Case': 370018,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'CUMBERLAND (51)',
#                'CrashDate': '/Date(1452983580000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 370019,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'CURRITUCK (53)',
#                'CrashDate': '/Date(1452719100000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 4,
#                'St_Case': 370020,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'DAVIDSON (57)',
#                'CrashDate': '/Date(1451694480000-0500)/',
#                'Fatals': 1,
#                'Peds': 1,
#                'Persons': 3,
#                'St_Case': 370021,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'DAVIDSON (57)',
#                'CrashDate': '/Date(1452390480000-0500)/',
#                'Fatals': 1,
#                'Peds': 1,
#                'Persons': 1,
#                'St_Case': 370022,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'DAVIDSON (57)',
#                'CrashDate': '/Date(1454204760000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 370023,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'DAVIE (59)',
#                'CrashDate': '/Date(1454200620000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 8,
#                'St_Case': 370024,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 3},
#               {'CountyName': 'DURHAM (63)',
#                'CrashDate': '/Date(1451966880000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370025,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'FORSYTH (67)',
#                'CrashDate': '/Date(1453324680000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 4,
#                'St_Case': 370026,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'GASTON (71)',
#                'CrashDate': '/Date(1452485820000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 370027,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'GASTON (71)',
#                'CrashDate': '/Date(1454138100000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370028,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'GRANVILLE (77)',
#                'CrashDate': '/Date(1452312780000-0500)/',
#                'Fatals': 2,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 370029,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'GUILFORD (81)',
#                'CrashDate': '/Date(1453127580000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 370030,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'HARNETT (85)',
#                'CrashDate': '/Date(1453003920000-0500)/',
#                'Fatals': 2,
#                'Peds': 3,
#                'Persons': 1,
#                'St_Case': 370031,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'HAYWOOD (87)',
#                'CrashDate': '/Date(1453859220000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370032,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'HOKE (93)',
#                'CrashDate': '/Date(1451778840000-0500)/',
#                'Fatals': 1,
#                'Peds': 1,
#                'Persons': 2,
#                'St_Case': 370033,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'IREDELL (97)',
#                'CrashDate': '/Date(1452813900000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 370034,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'IREDELL (97)',
#                'CrashDate': '/Date(1453488600000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 5,
#                'St_Case': 370035,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'JOHNSTON (101)',
#                'CrashDate': '/Date(1452554760000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 4,
#                'St_Case': 370036,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'JOHNSTON (101)',
#                'CrashDate': '/Date(1453468860000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 3,
#                'St_Case': 370037,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'LENOIR (107)',
#                'CrashDate': '/Date(1453206720000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 370038,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'LENOIR (107)',
#                'CrashDate': '/Date(1453838520000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 370039,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'LENOIR (107)',
#                'CrashDate': '/Date(1453872660000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 370040,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'MCDOWELL (111)',
#                'CrashDate': '/Date(1453592460000-0500)/',
#                'Fatals': 1,
#                'Peds': 1,
#                'Persons': 2,
#                'St_Case': 370041,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'MECKLENBURG (119)',
#                'CrashDate': '/Date(1452559020000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370042,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'MECKLENBURG (119)',
#                'CrashDate': '/Date(1452877200000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 370043,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'MECKLENBURG (119)',
#                'CrashDate': '/Date(1453068360000-0500)/',
#                'Fatals': 1,
#                'Peds': 1,
#                'Persons': 6,
#                'St_Case': 370044,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'MECKLENBURG (119)',
#                'CrashDate': '/Date(1453249560000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 5,
#                'St_Case': 370045,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'MECKLENBURG (119)',
#                'CrashDate': '/Date(1454042940000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 370046,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'NASH (127)',
#                'CrashDate': '/Date(1453936440000-0500)/',
#                'Fatals': 1,
#                'Peds': 1,
#                'Persons': 1,
#                'St_Case': 370047,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'NASH (127)',
#                'CrashDate': '/Date(1453989960000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 3,
#                'St_Case': 370048,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'ONSLOW (133)',
#                'CrashDate': '/Date(1451878860000-0500)/',
#                'Fatals': 1,
#                'Peds': 1,
#                'Persons': 1,
#                'St_Case': 370049,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'ONSLOW (133)',
#                'CrashDate': '/Date(1452752520000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370050,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'ONSLOW (133)',
#                'CrashDate': '/Date(1453860420000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370051,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'ONSLOW (133)',
#                'CrashDate': '/Date(1454282040000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 3,
#                'St_Case': 370052,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 3},
#               {'CountyName': 'PERSON (145)',
#                'CrashDate': '/Date(1453420800000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 370053,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'PITT (147)',
#                'CrashDate': '/Date(1453776060000-0500)/',
#                'Fatals': 1,
#                'Peds': 1,
#                'Persons': 1,
#                'St_Case': 370054,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'POLK (149)',
#                'CrashDate': '/Date(1454051700000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370055,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'RANDOLPH (151)',
#                'CrashDate': '/Date(1453835100000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 5,
#                'St_Case': 370056,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'RICHMOND (153)',
#                'CrashDate': '/Date(1453422480000-0500)/',
#                'Fatals': 2,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 370057,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'ROBESON (155)',
#                'CrashDate': '/Date(1451809560000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370058,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'ROBESON (155)',
#                'CrashDate': '/Date(1453809000000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 3,
#                'St_Case': 370059,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 3},
#               {'CountyName': 'ROWAN (159)',
#                'CrashDate': '/Date(1452664680000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370060,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'ROWAN (159)',
#                'CrashDate': '/Date(1452797940000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 370061,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'ROWAN (159)',
#                'CrashDate': '/Date(1454288220000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 370062,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'SAMPSON (163)',
#                'CrashDate': '/Date(1452125460000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370063,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'SAMPSON (163)',
#                'CrashDate': '/Date(1452795600000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 5,
#                'St_Case': 370064,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'SAMPSON (163)',
#                'CrashDate': '/Date(1452442440000-0500)/',
#                'Fatals': 1,
#                'Peds': 1,
#                'Persons': 1,
#                'St_Case': 370065,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'SAMPSON (163)',
#                'CrashDate': '/Date(1454234760000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 3,
#                'St_Case': 370066,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'SCOTLAND (165)',
#                'CrashDate': '/Date(1453948020000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 3,
#                'St_Case': 370067,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'STOKES (169)',
#                'CrashDate': '/Date(1453329900000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370068,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'SURRY (171)',
#                'CrashDate': '/Date(1452286500000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 370069,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'SURRY (171)',
#                'CrashDate': '/Date(1454040060000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370070,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'UNION (179)',
#                'CrashDate': '/Date(1453348020000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370071,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'UNION (179)',
#                'CrashDate': '/Date(1453603440000-0500)/',
#                'Fatals': 1,
#                'Peds': 1,
#                'Persons': 1,
#                'St_Case': 370072,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'VANCE (181)',
#                'CrashDate': '/Date(1452122760000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370073,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'WAKE (183)',
#                'CrashDate': '/Date(1451936640000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 370074,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'WAKE (183)',
#                'CrashDate': '/Date(1453894500000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370075,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'WAKE (183)',
#                'CrashDate': '/Date(1453929960000-0500)/',
#                'Fatals': 1,
#                'Peds': 1,
#                'Persons': 1,
#                'St_Case': 370076,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'WAYNE (191)',
#                'CrashDate': '/Date(1452358560000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370077,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'WILKES (193)',
#                'CrashDate': '/Date(1453335600000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 3,
#                'St_Case': 370079,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'DURHAM (63)',
#                'CrashDate': '/Date(1453852800000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 370080,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'GUILFORD (81)',
#                'CrashDate': '/Date(1452799260000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 4,
#                'St_Case': 370081,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'LEE (105)',
#                'CrashDate': '/Date(1452464340000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370082,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'WILSON (195)',
#                'CrashDate': '/Date(1453673820000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 3,
#                'St_Case': 370083,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'BRUNSWICK (19)',
#                'CrashDate': '/Date(1454717160000-0500)/',
#                'Fatals': 1,
#                'Peds': 1,
#                'Persons': 1,
#                'St_Case': 370084,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'BRUNSWICK (19)',
#                'CrashDate': '/Date(1455094800000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 3,
#                'St_Case': 370085,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'BUNCOMBE (21)',
#                'CrashDate': '/Date(1454735820000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 370086,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'BUNCOMBE (21)',
#                'CrashDate': '/Date(1455132540000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 3,
#                'St_Case': 370087,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'BUNCOMBE (21)',
#                'CrashDate': '/Date(1455765720000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370088,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'BUNCOMBE (21)',
#                'CrashDate': '/Date(1456609080000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 4,
#                'St_Case': 370089,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'BURKE (23)',
#                'CrashDate': '/Date(1456356600000-0500)/',
#                'Fatals': 1,
#                'Peds': 1,
#                'Persons': 2,
#                'St_Case': 370090,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'CHOWAN (41)',
#                'CrashDate': '/Date(1455675660000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370091,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'CLEVELAND (45)',
#                'CrashDate': '/Date(1456716840000-0500)/',
#                'Fatals': 2,
#                'Peds': 2,
#                'Persons': 1,
#                'St_Case': 370092,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'COLUMBUS (47)',
#                'CrashDate': '/Date(1455045120000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 370093,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'CRAVEN (49)',
#                'CrashDate': '/Date(1454895060000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370094,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'CUMBERLAND (51)',
#                'CrashDate': '/Date(1456642260000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 3,
#                'St_Case': 370095,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'DAVIDSON (57)',
#                'CrashDate': '/Date(1454384160000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 370096,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'DAVIDSON (57)',
#                'CrashDate': '/Date(1455074400000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 3,
#                'St_Case': 370097,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'DAVIDSON (57)',
#                'CrashDate': '/Date(1455368400000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370098,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'DAVIDSON (57)',
#                'CrashDate': '/Date(1456365840000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 3,
#                'St_Case': 370099,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'DURHAM (63)',
#                'CrashDate': '/Date(1455003540000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370100,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'FORSYTH (67)',
#                'CrashDate': '/Date(1454528400000-0500)/',
#                'Fatals': 3,
#                'Peds': 0,
#                'Persons': 5,
#                'St_Case': 370101,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 3},
#               {'CountyName': 'FORSYTH (67)',
#                'CrashDate': '/Date(1455920160000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 370102,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'FRANKLIN (69)',
#                'CrashDate': '/Date(1454882160000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370103,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'GASTON (71)',
#                'CrashDate': '/Date(1455807600000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370104,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 4},
#               {'CountyName': 'GASTON (71)',
#                'CrashDate': '/Date(1454461620000-0500)/',
#                'Fatals': 1,
#                'Peds': 1,
#                'Persons': 1,
#                'St_Case': 370105,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'GATES (73)',
#                'CrashDate': '/Date(1455050700000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 4,
#                'St_Case': 370106,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'GUILFORD (81)',
#                'CrashDate': '/Date(1454605020000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370107,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'GUILFORD (81)',
#                'CrashDate': '/Date(1454859420000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 4,
#                'St_Case': 370108,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'GUILFORD (81)',
#                'CrashDate': '/Date(1456807080000-0500)/',
#                'Fatals': 1,
#                'Peds': 1,
#                'Persons': 1,
#                'St_Case': 370109,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'HARNETT (85)',
#                'CrashDate': '/Date(1454402940000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 370110,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'JOHNSTON (101)',
#                'CrashDate': '/Date(1454677380000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370111,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'JOHNSTON (101)',
#                'CrashDate': '/Date(1455754140000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 370112,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'JOHNSTON (101)',
#                'CrashDate': '/Date(1455798780000-0500)/',
#                'Fatals': 2,
#                'Peds': 0,
#                'Persons': 3,
#                'St_Case': 370113,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'LEE (105)',
#                'CrashDate': '/Date(1454368920000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370114,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'LENOIR (107)',
#                'CrashDate': '/Date(1454782620000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 4,
#                'St_Case': 370115,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'LENOIR (107)',
#                'CrashDate': '/Date(1456170120000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 370116,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'LINCOLN (109)',
#                'CrashDate': '/Date(1455411660000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 4,
#                'St_Case': 370117,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 3},
#               {'CountyName': 'LINCOLN (109)',
#                'CrashDate': '/Date(1455541740000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 3,
#                'St_Case': 370118,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'MARTIN (117)',
#                'CrashDate': '/Date(1455344640000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370119,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'MECKLENBURG (119)',
#                'CrashDate': '/Date(1456731360000-0500)/',
#                'Fatals': 1,
#                'Peds': 1,
#                'Persons': 1,
#                'St_Case': 370120,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'MITCHELL (121)',
#                'CrashDate': '/Date(1455373080000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 370121,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'MONTGOMERY (123)',
#                'CrashDate': '/Date(1454347500000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370122,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'MOORE (125)',
#                'CrashDate': '/Date(1454618940000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370123,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'MOORE (125)',
#                'CrashDate': '/Date(1455799500000-0500)/',
#                'Fatals': 2,
#                'Peds': 1,
#                'Persons': 2,
#                'St_Case': 370124,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'ONSLOW (133)',
#                'CrashDate': '/Date(1455016260000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370125,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'PASQUOTANK (139)',
#                'CrashDate': '/Date(1454887440000-0500)/',
#                'Fatals': 1,
#                'Peds': 1,
#                'Persons': 1,
#                'St_Case': 370126,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'PASQUOTANK (139)',
#                'CrashDate': '/Date(1455950400000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370127,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'PITT (147)',
#                'CrashDate': '/Date(1455151260000-0500)/',
#                'Fatals': 1,
#                'Peds': 1,
#                'Persons': 4,
#                'St_Case': 370128,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'PITT (147)',
#                'CrashDate': '/Date(1455303300000-0500)/',
#                'Fatals': 2,
#                'Peds': 0,
#                'Persons': 5,
#                'St_Case': 370129,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'PITT (147)',
#                'CrashDate': '/Date(1455993900000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370130,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'PITT (147)',
#                'CrashDate': '/Date(1456404240000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 370131,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'RANDOLPH (151)',
#                'CrashDate': '/Date(1455876360000-0500)/',
#                'Fatals': 1,
#                'Peds': 1,
#                'Persons': 1,
#                'St_Case': 370132,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'ROBESON (155)',
#                'CrashDate': '/Date(1454537820000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 370134,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'ROBESON (155)',
#                'CrashDate': '/Date(1454598180000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 3,
#                'St_Case': 370135,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'ROBESON (155)',
#                'CrashDate': '/Date(1454804040000-0500)/',
#                'Fatals': 1,
#                'Peds': 1,
#                'Persons': 1,
#                'St_Case': 370136,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'ROCKINGHAM (157)',
#                'CrashDate': '/Date(1454910420000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370137,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'SCOTLAND (165)',
#                'CrashDate': '/Date(1454754780000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370138,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'STOKES (169)',
#                'CrashDate': '/Date(1455715740000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370139,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'UNION (179)',
#                'CrashDate': '/Date(1454992860000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 370140,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'UNION (179)',
#                'CrashDate': '/Date(1456190940000-0500)/',
#                'Fatals': 1,
#                'Peds': 1,
#                'Persons': 2,
#                'St_Case': 370141,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'VANCE (181)',
#                'CrashDate': '/Date(1454604180000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370142,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'WAKE (183)',
#                'CrashDate': '/Date(1454647320000-0500)/',
#                'Fatals': 1,
#                'Peds': 1,
#                'Persons': 2,
#                'St_Case': 370143,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'WAKE (183)',
#                'CrashDate': '/Date(1454850420000-0500)/',
#                'Fatals': 1,
#                'Peds': 1,
#                'Persons': 1,
#                'St_Case': 370144,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'WAKE (183)',
#                'CrashDate': '/Date(1455532200000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 370145,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'WAKE (183)',
#                'CrashDate': '/Date(1455891660000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 370146,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'WAKE (183)',
#                'CrashDate': '/Date(1456041180000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 4,
#                'St_Case': 370147,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'WAKE (183)',
# ...
#                'CrashDate': '/Date(1512454200000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 371268,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'JOHNSTON (101)',
#                'CrashDate': '/Date(1512265860000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 4,
#                'St_Case': 371269,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'JOHNSTON (101)',
#                'CrashDate': '/Date(1512729420000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 371270,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'JOHNSTON (101)',
#                'CrashDate': '/Date(1513395900000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 371271,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'LEE (105)',
#                'CrashDate': '/Date(1512886920000-0500)/',
#                'Fatals': 2,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 371272,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'MECKLENBURG (119)',
#                'CrashDate': '/Date(1512274500000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 16,
#                'St_Case': 371273,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'MECKLENBURG (119)',
#                'CrashDate': '/Date(1512513900000-0500)/',
#                'Fatals': 1,
#                'Peds': 1,
#                'Persons': 2,
#                'St_Case': 371274,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'MECKLENBURG (119)',
#                'CrashDate': '/Date(1512835500000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 3,
#                'St_Case': 371275,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'MECKLENBURG (119)',
#                'CrashDate': '/Date(1513014600000-0500)/',
#                'Fatals': 1,
#                'Peds': 1,
#                'Persons': 1,
#                'St_Case': 371276,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'MECKLENBURG (119)',
#                'CrashDate': '/Date(1512890280000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 7,
#                'St_Case': 371277,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 4},
#               {'CountyName': 'MECKLENBURG (119)',
#                'CrashDate': '/Date(1513399800000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 6,
#                'St_Case': 371278,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 3},
#               {'CountyName': 'MECKLENBURG (119)',
#                'CrashDate': '/Date(1513641480000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 7,
#                'St_Case': 371279,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 4},
#               {'CountyName': 'MECKLENBURG (119)',
#                'CrashDate': '/Date(1513967220000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 5,
#                'St_Case': 371280,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'MECKLENBURG (119)',
#                'CrashDate': '/Date(1514143680000-0500)/',
#                'Fatals': 1,
#                'Peds': 1,
#                'Persons': 1,
#                'St_Case': 371281,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'MONTGOMERY (123)',
#                'CrashDate': '/Date(1513168680000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 4,
#                'St_Case': 371282,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'MONTGOMERY (123)',
#                'CrashDate': '/Date(1513543980000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 371283,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'MOORE (125)',
#                'CrashDate': '/Date(1512196560000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 371284,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'MOORE (125)',
#                'CrashDate': '/Date(1512676260000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 371285,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'NEW HANOVER (129)',
#                'CrashDate': '/Date(1512253500000-0500)/',
#                'Fatals': 1,
#                'Peds': 1,
#                'Persons': 9,
#                'St_Case': 371286,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 5},
#               {'CountyName': 'ONSLOW (133)',
#                'CrashDate': '/Date(1513992900000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 3,
#                'St_Case': 371287,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'PERSON (145)',
#                'CrashDate': '/Date(1512406380000-0500)/',
#                'Fatals': 1,
#                'Peds': 1,
#                'Persons': 1,
#                'St_Case': 371288,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'PERSON (145)',
#                'CrashDate': '/Date(1513725180000-0500)/',
#                'Fatals': 2,
#                'Peds': 0,
#                'Persons': 3,
#                'St_Case': 371289,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'PITT (147)',
#                'CrashDate': '/Date(1513487820000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 371290,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'PITT (147)',
#                'CrashDate': '/Date(1513898400000-0500)/',
#                'Fatals': 1,
#                'Peds': 1,
#                'Persons': 1,
#                'St_Case': 371291,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'RANDOLPH (151)',
#                'CrashDate': '/Date(1513287120000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 371292,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'ROBESON (155)',
#                'CrashDate': '/Date(1512670620000-0500)/',
#                'Fatals': 2,
#                'Peds': 0,
#                'Persons': 4,
#                'St_Case': 371293,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'ROBESON (155)',
#                'CrashDate': '/Date(1512772380000-0500)/',
#                'Fatals': 1,
#                'Peds': 1,
#                'Persons': 2,
#                'St_Case': 371294,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'ROBESON (155)',
#                'CrashDate': '/Date(1513540140000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 6,
#                'St_Case': 371295,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 3},
#               {'CountyName': 'ROBESON (155)',
#                'CrashDate': '/Date(1514258400000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 371296,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'ROCKINGHAM (157)',
#                'CrashDate': '/Date(1513908360000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 371297,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'SAMPSON (163)',
#                'CrashDate': '/Date(1513889940000-0500)/',
#                'Fatals': 2,
#                'Peds': 0,
#                'Persons': 5,
#                'St_Case': 371298,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'SAMPSON (163)',
#                'CrashDate': '/Date(1513933200000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 371299,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'SAMPSON (163)',
#                'CrashDate': '/Date(1513957140000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 371300,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'STANLY (167)',
#                'CrashDate': '/Date(1512770760000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 4,
#                'St_Case': 371301,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'STANLY (167)',
#                'CrashDate': '/Date(1513131120000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 371302,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'SURRY (171)',
#                'CrashDate': '/Date(1513794420000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 371303,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'UNION (179)',
#                'CrashDate': '/Date(1513284840000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 371304,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'UNION (179)',
#                'CrashDate': '/Date(1514528460000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 371305,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'WAKE (183)',
#                'CrashDate': '/Date(1512353760000-0500)/',
#                'Fatals': 1,
#                'Peds': 1,
#                'Persons': 1,
#                'St_Case': 371306,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'WAKE (183)',
#                'CrashDate': '/Date(1513504440000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 371307,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'WAKE (183)',
#                'CrashDate': '/Date(1513679040000-0500)/',
#                'Fatals': 1,
#                'Peds': 1,
#                'Persons': 2,
#                'St_Case': 371308,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'WAYNE (191)',
#                'CrashDate': '/Date(1514637720000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 371309,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'WILSON (195)',
#                'CrashDate': '/Date(1514695320000-0500)/',
#                'Fatals': 3,
#                'Peds': 0,
#                'Persons': 4,
#                'St_Case': 371310,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'MECKLENBURG (119)',
#                'CrashDate': '/Date(1512733080000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 4,
#                'St_Case': 371311,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2},
#               {'CountyName': 'RANDOLPH (151)',
#                'CrashDate': '/Date(1514765400000-0500)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 1,
#                'St_Case': 371312,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'WAKE (183)',
#                'CrashDate': '/Date(1514422440000-0500)/',
#                'Fatals': 1,
#                'Peds': 1,
#                'Persons': 1,
#                'St_Case': 371313,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'GUILFORD (81)',
#                'CrashDate': '/Date(1508451960000-0400)/',
#                'Fatals': 1,
#                'Peds': 0,
#                'Persons': 2,
#                'St_Case': 371314,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 1},
#               {'CountyName': 'ANSON (7)',
#                'CrashDate': '/Date(1490760180000-0400)/',
#                'Fatals': 2,
#                'Peds': 0,
#                'Persons': 5,
#                'St_Case': 371315,
#                'State': 37,
#                'StateName': 'North Carolina',
#                'TotalVehicles': 2}]],
#  'SearchCriteria': 'State(s): 37 | FromYear: 2016 | ToYear: 2019 | '
#                    'MinNumOfVehicles: 1 | MaxNumOfVehicles: 6'}

# %%
# Pretty Print the output of the JSON
response1 = requests.get(url1).json()
print(json.dumps(response1, indent=4, sort_keys=True))
# Out:
# {
#     "Count": 3970,
#     "Message": "Results returned successfully",
#     "Results": [
#         [
#             {
#                 "CountyName": "ASHE (9)",
#                 "CrashDate": "/Date(1453317000000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 3,
#                 "St_Case": 370001,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "AVERY (11)",
#                 "CrashDate": "/Date(1453405320000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 370002,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "AVERY (11)",
#                 "CrashDate": "/Date(1453317480000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 3,
#                 "St_Case": 370003,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "BEAUFORT (13)",
#                 "CrashDate": "/Date(1452857820000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 370004,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "BERTIE (15)",
#                 "CrashDate": "/Date(1451951700000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 1,
#                 "Persons": 1,
#                 "St_Case": 370005,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "BLADEN (17)",
#                 "CrashDate": "/Date(1453757280000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 370006,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "CABARRUS (25)",
#                 "CrashDate": "/Date(1451866500000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 3,
#                 "St_Case": 370007,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "CABARRUS (25)",
#                 "CrashDate": "/Date(1452741240000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370008,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "CABARRUS (25)",
#                 "CrashDate": "/Date(1454280480000-0500)/",
#                 "Fatals": 2,
#                 "Peds": 0,
#                 "Persons": 4,
#                 "St_Case": 370009,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "CATAWBA (35)",
#                 "CrashDate": "/Date(1453421760000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 1,
#                 "Persons": 2,
#                 "St_Case": 370010,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "CATAWBA (35)",
#                 "CrashDate": "/Date(1453446000000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370011,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "CHATHAM (37)",
#                 "CrashDate": "/Date(1452579060000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370012,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "CHATHAM (37)",
#                 "CrashDate": "/Date(1453009500000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370013,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "CHEROKEE (39)",
#                 "CrashDate": "/Date(1451922900000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 370014,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "COLUMBUS (47)",
#                 "CrashDate": "/Date(1454099580000-0500)/",
#                 "Fatals": 2,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 370015,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "CRAVEN (49)",
#                 "CrashDate": "/Date(1452091980000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 8,
#                 "St_Case": 370016,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 5
#             },
#             {
#                 "CountyName": "CRAVEN (49)",
#                 "CrashDate": "/Date(1453863960000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370017,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "CUMBERLAND (51)",
#                 "CrashDate": "/Date(1452920100000-0500)/",
#                 "Fatals": 2,
#                 "Peds": 0,
#                 "Persons": 3,
#                 "St_Case": 370018,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "CUMBERLAND (51)",
#                 "CrashDate": "/Date(1452983580000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 370019,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "CURRITUCK (53)",
#                 "CrashDate": "/Date(1452719100000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 4,
#                 "St_Case": 370020,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "DAVIDSON (57)",
#                 "CrashDate": "/Date(1451694480000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 1,
#                 "Persons": 3,
#                 "St_Case": 370021,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "DAVIDSON (57)",
#                 "CrashDate": "/Date(1452390480000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 1,
#                 "Persons": 1,
#                 "St_Case": 370022,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "DAVIDSON (57)",
#                 "CrashDate": "/Date(1454204760000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 370023,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "DAVIE (59)",
#                 "CrashDate": "/Date(1454200620000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 8,
#                 "St_Case": 370024,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 3
#             },
#             {
#                 "CountyName": "DURHAM (63)",
#                 "CrashDate": "/Date(1451966880000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370025,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "FORSYTH (67)",
#                 "CrashDate": "/Date(1453324680000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 4,
#                 "St_Case": 370026,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "GASTON (71)",
#                 "CrashDate": "/Date(1452485820000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 370027,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "GASTON (71)",
#                 "CrashDate": "/Date(1454138100000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370028,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "GRANVILLE (77)",
#                 "CrashDate": "/Date(1452312780000-0500)/",
#                 "Fatals": 2,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 370029,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "GUILFORD (81)",
#                 "CrashDate": "/Date(1453127580000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 370030,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "HARNETT (85)",
#                 "CrashDate": "/Date(1453003920000-0500)/",
#                 "Fatals": 2,
#                 "Peds": 3,
#                 "Persons": 1,
#                 "St_Case": 370031,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "HAYWOOD (87)",
#                 "CrashDate": "/Date(1453859220000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370032,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "HOKE (93)",
#                 "CrashDate": "/Date(1451778840000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 1,
#                 "Persons": 2,
#                 "St_Case": 370033,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "IREDELL (97)",
#                 "CrashDate": "/Date(1452813900000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 370034,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "IREDELL (97)",
#                 "CrashDate": "/Date(1453488600000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 5,
#                 "St_Case": 370035,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "JOHNSTON (101)",
#                 "CrashDate": "/Date(1452554760000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 4,
#                 "St_Case": 370036,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "JOHNSTON (101)",
#                 "CrashDate": "/Date(1453468860000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 3,
#                 "St_Case": 370037,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "LENOIR (107)",
#                 "CrashDate": "/Date(1453206720000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 370038,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "LENOIR (107)",
#                 "CrashDate": "/Date(1453838520000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 370039,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "LENOIR (107)",
#                 "CrashDate": "/Date(1453872660000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 370040,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "MCDOWELL (111)",
#                 "CrashDate": "/Date(1453592460000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 1,
#                 "Persons": 2,
#                 "St_Case": 370041,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "MECKLENBURG (119)",
#                 "CrashDate": "/Date(1452559020000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370042,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "MECKLENBURG (119)",
#                 "CrashDate": "/Date(1452877200000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 370043,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "MECKLENBURG (119)",
#                 "CrashDate": "/Date(1453068360000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 1,
#                 "Persons": 6,
#                 "St_Case": 370044,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "MECKLENBURG (119)",
#                 "CrashDate": "/Date(1453249560000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 5,
#                 "St_Case": 370045,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "MECKLENBURG (119)",
#                 "CrashDate": "/Date(1454042940000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 370046,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "NASH (127)",
#                 "CrashDate": "/Date(1453936440000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 1,
#                 "Persons": 1,
#                 "St_Case": 370047,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "NASH (127)",
#                 "CrashDate": "/Date(1453989960000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 3,
#                 "St_Case": 370048,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "ONSLOW (133)",
#                 "CrashDate": "/Date(1451878860000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 1,
#                 "Persons": 1,
#                 "St_Case": 370049,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "ONSLOW (133)",
#                 "CrashDate": "/Date(1452752520000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370050,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "ONSLOW (133)",
#                 "CrashDate": "/Date(1453860420000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370051,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "ONSLOW (133)",
#                 "CrashDate": "/Date(1454282040000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 3,
#                 "St_Case": 370052,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 3
#             },
#             {
#                 "CountyName": "PERSON (145)",
#                 "CrashDate": "/Date(1453420800000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 370053,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "PITT (147)",
#                 "CrashDate": "/Date(1453776060000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 1,
#                 "Persons": 1,
#                 "St_Case": 370054,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "POLK (149)",
#                 "CrashDate": "/Date(1454051700000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370055,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "RANDOLPH (151)",
#                 "CrashDate": "/Date(1453835100000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 5,
#                 "St_Case": 370056,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "RICHMOND (153)",
#                 "CrashDate": "/Date(1453422480000-0500)/",
#                 "Fatals": 2,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 370057,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "ROBESON (155)",
#                 "CrashDate": "/Date(1451809560000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370058,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "ROBESON (155)",
#                 "CrashDate": "/Date(1453809000000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 3,
#                 "St_Case": 370059,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 3
#             },
#             {
#                 "CountyName": "ROWAN (159)",
#                 "CrashDate": "/Date(1452664680000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370060,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "ROWAN (159)",
#                 "CrashDate": "/Date(1452797940000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 370061,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "ROWAN (159)",
#                 "CrashDate": "/Date(1454288220000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 370062,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "SAMPSON (163)",
#                 "CrashDate": "/Date(1452125460000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370063,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "SAMPSON (163)",
#                 "CrashDate": "/Date(1452795600000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 5,
#                 "St_Case": 370064,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "SAMPSON (163)",
#                 "CrashDate": "/Date(1452442440000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 1,
#                 "Persons": 1,
#                 "St_Case": 370065,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "SAMPSON (163)",
#                 "CrashDate": "/Date(1454234760000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 3,
#                 "St_Case": 370066,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "SCOTLAND (165)",
#                 "CrashDate": "/Date(1453948020000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 3,
#                 "St_Case": 370067,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "STOKES (169)",
#                 "CrashDate": "/Date(1453329900000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370068,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "SURRY (171)",
#                 "CrashDate": "/Date(1452286500000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 370069,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "SURRY (171)",
#                 "CrashDate": "/Date(1454040060000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370070,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "UNION (179)",
#                 "CrashDate": "/Date(1453348020000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370071,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "UNION (179)",
#                 "CrashDate": "/Date(1453603440000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 1,
#                 "Persons": 1,
#                 "St_Case": 370072,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "VANCE (181)",
#                 "CrashDate": "/Date(1452122760000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370073,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "WAKE (183)",
#                 "CrashDate": "/Date(1451936640000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 370074,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "WAKE (183)",
#                 "CrashDate": "/Date(1453894500000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370075,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "WAKE (183)",
#                 "CrashDate": "/Date(1453929960000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 1,
#                 "Persons": 1,
#                 "St_Case": 370076,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "WAYNE (191)",
#                 "CrashDate": "/Date(1452358560000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370077,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "WILKES (193)",
#                 "CrashDate": "/Date(1453335600000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 3,
#                 "St_Case": 370079,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "DURHAM (63)",
#                 "CrashDate": "/Date(1453852800000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 370080,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "GUILFORD (81)",
#                 "CrashDate": "/Date(1452799260000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 4,
#                 "St_Case": 370081,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "LEE (105)",
#                 "CrashDate": "/Date(1452464340000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370082,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "WILSON (195)",
#                 "CrashDate": "/Date(1453673820000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 3,
#                 "St_Case": 370083,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "BRUNSWICK (19)",
#                 "CrashDate": "/Date(1454717160000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 1,
#                 "Persons": 1,
#                 "St_Case": 370084,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "BRUNSWICK (19)",
#                 "CrashDate": "/Date(1455094800000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 3,
#                 "St_Case": 370085,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "BUNCOMBE (21)",
#                 "CrashDate": "/Date(1454735820000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 370086,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "BUNCOMBE (21)",
#                 "CrashDate": "/Date(1455132540000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 3,
#                 "St_Case": 370087,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "BUNCOMBE (21)",
#                 "CrashDate": "/Date(1455765720000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370088,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "BUNCOMBE (21)",
#                 "CrashDate": "/Date(1456609080000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 4,
#                 "St_Case": 370089,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "BURKE (23)",
#                 "CrashDate": "/Date(1456356600000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 1,
#                 "Persons": 2,
#                 "St_Case": 370090,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "CHOWAN (41)",
#                 "CrashDate": "/Date(1455675660000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370091,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "CLEVELAND (45)",
#                 "CrashDate": "/Date(1456716840000-0500)/",
#                 "Fatals": 2,
#                 "Peds": 2,
#                 "Persons": 1,
#                 "St_Case": 370092,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "COLUMBUS (47)",
#                 "CrashDate": "/Date(1455045120000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 370093,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "CRAVEN (49)",
#                 "CrashDate": "/Date(1454895060000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370094,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "CUMBERLAND (51)",
#                 "CrashDate": "/Date(1456642260000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 3,
#                 "St_Case": 370095,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "DAVIDSON (57)",
#                 "CrashDate": "/Date(1454384160000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 370096,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "DAVIDSON (57)",
#                 "CrashDate": "/Date(1455074400000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 3,
#                 "St_Case": 370097,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "DAVIDSON (57)",
#                 "CrashDate": "/Date(1455368400000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370098,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "DAVIDSON (57)",
#                 "CrashDate": "/Date(1456365840000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 3,
#                 "St_Case": 370099,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "DURHAM (63)",
#                 "CrashDate": "/Date(1455003540000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370100,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "FORSYTH (67)",
#                 "CrashDate": "/Date(1454528400000-0500)/",
#                 "Fatals": 3,
#                 "Peds": 0,
#                 "Persons": 5,
#                 "St_Case": 370101,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 3
#             },
#             {
#                 "CountyName": "FORSYTH (67)",
#                 "CrashDate": "/Date(1455920160000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 370102,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "FRANKLIN (69)",
#                 "CrashDate": "/Date(1454882160000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370103,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "GASTON (71)",
#                 "CrashDate": "/Date(1455807600000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370104,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 4
#             },
#             {
#                 "CountyName": "GASTON (71)",
#                 "CrashDate": "/Date(1454461620000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 1,
#                 "Persons": 1,
#                 "St_Case": 370105,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "GATES (73)",
#                 "CrashDate": "/Date(1455050700000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 4,
#                 "St_Case": 370106,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "GUILFORD (81)",
#                 "CrashDate": "/Date(1454605020000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370107,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "GUILFORD (81)",
#                 "CrashDate": "/Date(1454859420000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 4,
#                 "St_Case": 370108,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "GUILFORD (81)",
#                 "CrashDate": "/Date(1456807080000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 1,
#                 "Persons": 1,
#                 "St_Case": 370109,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "HARNETT (85)",
#                 "CrashDate": "/Date(1454402940000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 370110,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "JOHNSTON (101)",
#                 "CrashDate": "/Date(1454677380000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370111,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "JOHNSTON (101)",
#                 "CrashDate": "/Date(1455754140000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 370112,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "JOHNSTON (101)",
#                 "CrashDate": "/Date(1455798780000-0500)/",
#                 "Fatals": 2,
#                 "Peds": 0,
#                 "Persons": 3,
#                 "St_Case": 370113,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "LEE (105)",
#                 "CrashDate": "/Date(1454368920000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370114,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "LENOIR (107)",
#                 "CrashDate": "/Date(1454782620000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 4,
#                 "St_Case": 370115,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "LENOIR (107)",
#                 "CrashDate": "/Date(1456170120000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 370116,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "LINCOLN (109)",
#                 "CrashDate": "/Date(1455411660000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 4,
#                 "St_Case": 370117,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 3
#             },
#             {
#                 "CountyName": "LINCOLN (109)",
#                 "CrashDate": "/Date(1455541740000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 3,
#                 "St_Case": 370118,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "MARTIN (117)",
#                 "CrashDate": "/Date(1455344640000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370119,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "MECKLENBURG (119)",
#                 "CrashDate": "/Date(1456731360000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 1,
#                 "Persons": 1,
#                 "St_Case": 370120,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "MITCHELL (121)",
#                 "CrashDate": "/Date(1455373080000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 370121,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "MONTGOMERY (123)",
#                 "CrashDate": "/Date(1454347500000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370122,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "MOORE (125)",
#                 "CrashDate": "/Date(1454618940000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370123,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "MOORE (125)",
#                 "CrashDate": "/Date(1455799500000-0500)/",
#                 "Fatals": 2,
#                 "Peds": 1,
#                 "Persons": 2,
#                 "St_Case": 370124,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "ONSLOW (133)",
#                 "CrashDate": "/Date(1455016260000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370125,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "PASQUOTANK (139)",
#                 "CrashDate": "/Date(1454887440000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 1,
#                 "Persons": 1,
#                 "St_Case": 370126,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "PASQUOTANK (139)",
#                 "CrashDate": "/Date(1455950400000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370127,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "PITT (147)",
#                 "CrashDate": "/Date(1455151260000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 1,
#                 "Persons": 4,
#                 "St_Case": 370128,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "PITT (147)",
#                 "CrashDate": "/Date(1455303300000-0500)/",
#                 "Fatals": 2,
#                 "Peds": 0,
#                 "Persons": 5,
#                 "St_Case": 370129,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "PITT (147)",
#                 "CrashDate": "/Date(1455993900000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 370130,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "PITT (147)",
#                 "CrashDate": "/Date(1456404240000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 370131,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "RANDOLPH (151)",
#                 "CrashDate": "/Date(1455876360000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 1,
#                 "Persons": 1,
#                 "St_Case": 370132,
#                 "State": 37,
# ...
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "MECKLENBURG (119)",
#                 "CrashDate": "/Date(1512274500000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 16,
#                 "St_Case": 371273,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "MECKLENBURG (119)",
#                 "CrashDate": "/Date(1512513900000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 1,
#                 "Persons": 2,
#                 "St_Case": 371274,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "MECKLENBURG (119)",
#                 "CrashDate": "/Date(1512835500000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 3,
#                 "St_Case": 371275,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "MECKLENBURG (119)",
#                 "CrashDate": "/Date(1513014600000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 1,
#                 "Persons": 1,
#                 "St_Case": 371276,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "MECKLENBURG (119)",
#                 "CrashDate": "/Date(1512890280000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 7,
#                 "St_Case": 371277,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 4
#             },
#             {
#                 "CountyName": "MECKLENBURG (119)",
#                 "CrashDate": "/Date(1513399800000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 6,
#                 "St_Case": 371278,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 3
#             },
#             {
#                 "CountyName": "MECKLENBURG (119)",
#                 "CrashDate": "/Date(1513641480000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 7,
#                 "St_Case": 371279,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 4
#             },
#             {
#                 "CountyName": "MECKLENBURG (119)",
#                 "CrashDate": "/Date(1513967220000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 5,
#                 "St_Case": 371280,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "MECKLENBURG (119)",
#                 "CrashDate": "/Date(1514143680000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 1,
#                 "Persons": 1,
#                 "St_Case": 371281,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "MONTGOMERY (123)",
#                 "CrashDate": "/Date(1513168680000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 4,
#                 "St_Case": 371282,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "MONTGOMERY (123)",
#                 "CrashDate": "/Date(1513543980000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 371283,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "MOORE (125)",
#                 "CrashDate": "/Date(1512196560000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 371284,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "MOORE (125)",
#                 "CrashDate": "/Date(1512676260000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 371285,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "NEW HANOVER (129)",
#                 "CrashDate": "/Date(1512253500000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 1,
#                 "Persons": 9,
#                 "St_Case": 371286,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 5
#             },
#             {
#                 "CountyName": "ONSLOW (133)",
#                 "CrashDate": "/Date(1513992900000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 3,
#                 "St_Case": 371287,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "PERSON (145)",
#                 "CrashDate": "/Date(1512406380000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 1,
#                 "Persons": 1,
#                 "St_Case": 371288,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "PERSON (145)",
#                 "CrashDate": "/Date(1513725180000-0500)/",
#                 "Fatals": 2,
#                 "Peds": 0,
#                 "Persons": 3,
#                 "St_Case": 371289,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "PITT (147)",
#                 "CrashDate": "/Date(1513487820000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 371290,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "PITT (147)",
#                 "CrashDate": "/Date(1513898400000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 1,
#                 "Persons": 1,
#                 "St_Case": 371291,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "RANDOLPH (151)",
#                 "CrashDate": "/Date(1513287120000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 371292,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "ROBESON (155)",
#                 "CrashDate": "/Date(1512670620000-0500)/",
#                 "Fatals": 2,
#                 "Peds": 0,
#                 "Persons": 4,
#                 "St_Case": 371293,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "ROBESON (155)",
#                 "CrashDate": "/Date(1512772380000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 1,
#                 "Persons": 2,
#                 "St_Case": 371294,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "ROBESON (155)",
#                 "CrashDate": "/Date(1513540140000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 6,
#                 "St_Case": 371295,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 3
#             },
#             {
#                 "CountyName": "ROBESON (155)",
#                 "CrashDate": "/Date(1514258400000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 371296,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "ROCKINGHAM (157)",
#                 "CrashDate": "/Date(1513908360000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 371297,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "SAMPSON (163)",
#                 "CrashDate": "/Date(1513889940000-0500)/",
#                 "Fatals": 2,
#                 "Peds": 0,
#                 "Persons": 5,
#                 "St_Case": 371298,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "SAMPSON (163)",
#                 "CrashDate": "/Date(1513933200000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 371299,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "SAMPSON (163)",
#                 "CrashDate": "/Date(1513957140000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 371300,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "STANLY (167)",
#                 "CrashDate": "/Date(1512770760000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 4,
#                 "St_Case": 371301,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "STANLY (167)",
#                 "CrashDate": "/Date(1513131120000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 371302,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "SURRY (171)",
#                 "CrashDate": "/Date(1513794420000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 371303,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "UNION (179)",
#                 "CrashDate": "/Date(1513284840000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 371304,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "UNION (179)",
#                 "CrashDate": "/Date(1514528460000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 371305,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "WAKE (183)",
#                 "CrashDate": "/Date(1512353760000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 1,
#                 "Persons": 1,
#                 "St_Case": 371306,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "WAKE (183)",
#                 "CrashDate": "/Date(1513504440000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 371307,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "WAKE (183)",
#                 "CrashDate": "/Date(1513679040000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 1,
#                 "Persons": 2,
#                 "St_Case": 371308,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "WAYNE (191)",
#                 "CrashDate": "/Date(1514637720000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 371309,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "WILSON (195)",
#                 "CrashDate": "/Date(1514695320000-0500)/",
#                 "Fatals": 3,
#                 "Peds": 0,
#                 "Persons": 4,
#                 "St_Case": 371310,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "MECKLENBURG (119)",
#                 "CrashDate": "/Date(1512733080000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 4,
#                 "St_Case": 371311,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             },
#             {
#                 "CountyName": "RANDOLPH (151)",
#                 "CrashDate": "/Date(1514765400000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 1,
#                 "St_Case": 371312,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "WAKE (183)",
#                 "CrashDate": "/Date(1514422440000-0500)/",
#                 "Fatals": 1,
#                 "Peds": 1,
#                 "Persons": 1,
#                 "St_Case": 371313,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "GUILFORD (81)",
#                 "CrashDate": "/Date(1508451960000-0400)/",
#                 "Fatals": 1,
#                 "Peds": 0,
#                 "Persons": 2,
#                 "St_Case": 371314,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 1
#             },
#             {
#                 "CountyName": "ANSON (7)",
#                 "CrashDate": "/Date(1490760180000-0400)/",
#                 "Fatals": 2,
#                 "Peds": 0,
#                 "Persons": 5,
#                 "St_Case": 371315,
#                 "State": 37,
#                 "StateName": "North Carolina",
#                 "TotalVehicles": 2
#             }
#         ]
#     ],
#     "SearchCriteria": "State(s): 37 | FromYear: 2016 | ToYear: 2019 | MinNumOfVehicles: 1 | MaxNumOfVehicles: 6"
# }
